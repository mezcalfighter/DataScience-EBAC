# %%
import pandas as pd

df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Creacion de un stripplot (Grafico de Franjas / Bandas)
import seaborn as sns

sns.stripplot(data=df, y="writing score", x="math score", jitter=True)
# Out:
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
import matplotlib.pyplot as plt
fix, ax = plt.subplots()
sns.stripplot(data=df, y = "writing score", x="math score", jitter=True)
ax.axes.xaxis.set_ticks([])
plt.show
# Out:
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
fix, ax = plt.subplots()
sns.stripplot(data=df, y = "writing score", x="race/ethnicity", jitter=True)
ax.axes.xaxis.set_ticks([])
plt.show
# Out:
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Creacion de un swarmplot (Diagrama de enjambre)
# Busca colocar las observaciones de manera que no se empalmen
sns.swarmplot(data=df, y="writing score", x="race/ethnicity")
# Out:
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
# Creacion de un Boxplot (Diagrama de caja)
sns.boxplot(data=df, y="writing score",  x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creacion de un grafico de violin
# Mezcla de un boxplot con funcion de densidad Kernel
sns.violinplot(data=df,y="writing score", x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creacion de un lvplot (Letter-Value Plot)
# Mezcla del Boxplot y el ViolinPlot, conveniente para bases de datos grandes
sns.catplot(x="race/ethnicity",y="writing score",kind="boxen", data=df)
# Out:
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/emanuel/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Creacion de un barplot
sns.barplot(data=df, y="writing score",x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creacion de un barplot
sns.barplot(data=df, y="writing score",x="race/ethnicity", hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Grafico de un pointplot (Grafico de puntos)
sns.pointplot(data=df,y="writing score",x="race/ethnicity",hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creacion de un countplot (Grafico de puntos)
sns.countplot(data=df, y="race/ethnicity",hue="lunch")
# Out:
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
# Graficos de regresion con Regplot
sns.regplot(data=df, y="writing score",x="reading score",marker="+")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Grafico de residuales
sns.residplot(data=df,y="writing score",x="reading score")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Grafico de regresion con Regplot y media por valor de x
# Muy util para enfatizar tendendcias
import numpy as np
sns.regplot(data=df, y="writing score",x="reading score",x_estimator=np.mean)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Creacion de un mapa de calor para una matriz de correlacion
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Creacion de un mapa de calor para una matriz de correlacion
# ----> 2 sns.heatmap(df.corr())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Creacion de una tabla cruzada
pd.crosstab(df["gender"],df["race/ethnicity"], values=df["math score"], aggfunc="mean")
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
# Creacion de un mapa de calor para una tabla cruzada
sns.heatmap(pd.crosstab(df["gender"],df["race/ethnicity"], values=df["math score"], aggfunc="mean"), annot=True)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='gender'>
