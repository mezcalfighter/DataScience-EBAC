# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("co2-mm-mlo_csv.csv")
df
# Out:
#         Date  Decimal Date  Average  Interpolated  Trend  Number of Days  \
# 0    1958-03     1958.2027   315.70        314.43     -1           -9.99
# 1    1958-04     1958.2877   317.45        315.16     -1           -9.99
# 2    1958-05     1958.3699   317.51        314.71     -1           -9.99
# 3    1958-06     1958.4548   317.24        315.14     -1           -9.99
# 4    1958-07     1958.5370   315.86        315.18     -1           -9.99
# ..       ...           ...      ...           ...    ...             ...
# 786  2023-09     2023.7083   418.51        421.96     18            0.30
# 787  2023-10     2023.7917   418.82        422.12     27            0.47
# 788  2023-11     2023.8750   420.46        422.43     21            0.91
# 789  2023-12     2023.9583   421.86        422.56     20            0.70
# 790  2024-01     2024.0417   422.80        422.53     27            0.60
#
#     __parsed_extra
# 0          [-0.99]
# 1          [-0.99]
# 2          [-0.99]
# 3          [-0.99]
# 4          [-0.99]
# ..             ...
# 786         [0.14]
# 787         [0.17]
# 788         [0.38]
# 789          [0.3]
# 790         [0.22]
#
# [791 rows x 7 columns]

# %%
fechas = df[df["Date"] >= "2015-01-01"]

fig, ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use("ggplot")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()

# %%
# Re-inicializacion del estilo de frafico por "default"
plt.style.use("default")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()

# %%
# Estilo "bmh"
plt.style.use("bmh")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()

# %%
# Estilo "seaborn"
plt.style.use("seaborn-colorblind")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-colorblind'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Estilo "seaborn"
# ----> 2 plt.style.use("seaborn-colorblind")
#       3 fechas = df[df["Date"] >= "2015-01-01"]
#       5 fig,  ax = plt.subplots()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/style/core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn-colorblind' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
# Estilo "Tableau"
plt.style.use("tableau-colorblind10")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()

# %%
# Estilo "grayscale"
plt.style.use("grayscale")
fechas = df[df["Date"] >= "2015-01-01"]

fig,  ax = plt.subplots()
ax.plot(fechas["Date"],fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 2015-01-01 - 2018-09-01")
plt.ylabel("Emisiones de C02 promedio")
plt.show()

# %%
# Para guardar el archivo
fig.savefig("medallas.png")

# %%
# Para determinar en donde se guardo el archivo
import pathlib
pathlib.Path().resolve()
# Out:
# PosixPath('/home/emanuel/Documents/Learning/DataScience-EBAC/Ejercicios/Visualizacion de Datos Matplotlib')

# %%
ls
# Out:
#  co2-mm-mlo_csv.csv
# 'Comparticion de visualizaciones.ipynb'
# 'Graficacion de Series de Tiempo.ipynb'
#  Introduccion.ipynb
#  medallas.png
#  olympic-medals.csv
# 'Visualizaciones cuantitativas y  estadisticas.ipynb'

# %%
# Resolucion de 100 dpi's
fig.savefig("medallas.png",dpi=100)

# %%
# Formato JPG - Resolucion de 100 dpi's
fig.savefig("medallas.jpg",dpi=100)
