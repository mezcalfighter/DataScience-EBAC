# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("SYB66_246_202310_Population Growth, Fertility and Mortality Indicators.csv", encoding='latin1', skiprows=1)
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2010
# 1                       1  Total, all countries or areas  2010
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2010
# ...                   ...                            ...   ...
# 6751                  722                           SIDS  2022
# 6752                  722                           SIDS  2022
# 6753                  722                           SIDS  2022
# 6754                  722                           SIDS  2022
# 6755                  722                           SIDS  2022
#
#                                                  Series Value  \
# 0          Population annual rate of increase (percent)   1.3
# 1             Total fertility rate (children per women)   2.6
# ...

# %%
#infant = df[df["Series"] == "Infant mortality for both sexes (per 1,000 live births)"]
#population = df[df["Series"] == "Life expectancy at birth for both sexes (years)"]
infant = "Infant mortality for both sexes (per 1,000 live births)"
population = "Life expectancy at birth for both sexes (years)"

# %%
# Grafico de dispersion con regresion lineal por categorias de genero
sns.lmplot(data=df, x="population", y="infant", row="Region")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Grafico de dispersion con regresion lineal por categorias de genero
# ----> 2 sns.lmplot(data=df, x="population", y="infant", row="Region")
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
# ...
