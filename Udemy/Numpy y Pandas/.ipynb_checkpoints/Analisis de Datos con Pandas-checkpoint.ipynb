# %%
# Construida sobre Numpy
# Permite manipular gran cantidad de datos de fuentes heterogeneas (Big Data)

import pandas as pd
info_pais = {"pais":["Brasil","Mexico","Espana","Peru","Colombia","Venezuela"],
             "capital":["Brasisila","Ciudad de Mexico","Madrid","Lima","Bogota","Caracas"],
             "superficie (Mkm2)":[8.5,1.9,1.2,0.5,1.1,0.9]}

df = pd.DataFrame(info_pais)
df
# Out:
#         pais           capital  superficie (Mkm2)
# 0     Brasil         Brasisila                8.5
# 1     Mexico  Ciudad de Mexico                1.9
# 2     Espana            Madrid                1.2
# 3       Peru              Lima                0.5
# 4   Colombia            Bogota                1.1
# 5  Venezuela           Caracas                0.9

# %%
# Importar de un CSV
# df = pd.read_csv(r"file.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0, nrows=5, header = None) 
df = pd.read_csv(r"PEATONES_2020.csv", delimiter=";", encoding = "ISO-8859-1", nrows=5, index_col="IDENTIFICADOR")
df
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00       497                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00       244                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00       179                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00       174                1   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00       131                1   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# ...

# %%
df.head()
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00       497                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00       244                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00       179                1   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00       174                1   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00       131                1   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
# PERM_PEA02_PM01  Calle Fuencarral      22          28004
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# ...

# %%
df.groupby("NOMBRE_VIAL")
df.head(10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, PERM_PEA02_PM01 to PERM_PEA02_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FECHA                    5 non-null      object
#  1   HORA                     5 non-null      object
#  2   PEATONES                 5 non-null      int64
#  3   NÚMERO_DISTRITO          5 non-null      int64
#  4   DISTRITO                 5 non-null      object
#  5   NOMBRE_VIAL              5 non-null      object
#  6   NÚMERO                   5 non-null      int64
#  7   CÓDIGO_POSTAL            5 non-null      int64
#  8   OBSERVACIONES_DIRECCION  5 non-null      object
#  9   LATITUD                  5 non-null      object
#  10  LONGITUD                 5 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 652.0+ bytes

# %%
info_pais = {"pais":["Brasil","Mexico","Espana","Peru","Colombia","Venezuela"],
             "capital":["Brasisila","Ciudad de Mexico","Madrid","Lima","Bogota","Caracas"],
             "superficie (Mkm2)":[8.5,1.9,1.2,0.5,1.1,0.9]}

df = pd.DataFrame(info_pais)
df["capital"]
# Out:
# 0           Brasisila
# 1    Ciudad de Mexico
# 2              Madrid
# 3                Lima
# 4              Bogota
# 5             Caracas
# Name: capital, dtype: object

# %%
df[["capital","superficie (Mkm2)"]]
# Out:
#             capital  superficie (Mkm2)
# 0         Brasisila                8.5
# 1  Ciudad de Mexico                1.9
# 2            Madrid                1.2
# 3              Lima                0.5
# 4            Bogota                1.1
# 5           Caracas                0.9

# %%
df[2:5]
# Out:
#        pais capital  superficie (Mkm2)
# 2    Espana  Madrid                1.2
# 3      Peru    Lima                0.5
# 4  Colombia  Bogota                1.1

# %%
df[["capital","superficie (Mkm2)"],2:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['capital', 'superficie (Mkm2)'], slice(2, 5, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df[["capital","superficie (Mkm2)"],2:5]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
# ...

# %%
# Loc (Basada en las etiquetas) / iLoc (Basada en indices de posicion)
# Loc - df.loc["lista_nombre_filas","lista_nombre_columnas"]
df.loc[[0,1,2],['capital','superficie (Mkm2)']]

# Para seleccionar todos los datos podemos indicar :
# Out:
#             capital  superficie (Mkm2)
# 0         Brasisila                8.5
# 1  Ciudad de Mexico                1.9
# 2            Madrid                1.2
